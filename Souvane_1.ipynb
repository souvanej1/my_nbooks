# %% [markdown]
# # Janelle Souvane
# ## Phases of Analysis and Visualization

# %%
import pandas as pd
# poll_url = "C:\Users\janel\OneDrive\Documents\Jupyter Programminig\president_general_polls_2016.csv"
poll_url = r"C:\Users\janel\OneDrive\Documents\Jupyter Programminig\president_general_polls_2016.csv"
polls = pd.read_csv(poll_url, on_bad_lines='skip')

# %%
polls.head()
# Out:
#        cycle     branch        type                        matchup  \
# 10862   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 10620   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 6662    2016  President    now-cast  Clinton vs. Trump vs. Johnson
# 3022    2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 10716   2016  President  polls-only  Clinton vs. Trump vs. Johnson
#
#       forecastdate     state startdate    enddate              pollster grade  \
# 10862      11/8/16  Kentucky  9/9/2016  9/22/2016                 Ipsos    A-
# 10620      11/8/16     Maine  9/9/2016  9/29/2016                 Ipsos    A-
# 6662       11/8/16  Kentucky  9/9/2016  9/22/2016                 Ipsos    A-
# 3022       11/8/16      U.S.  9/9/2016  9/15/2016  CVOTER International    C+
# 10716      11/8/16    Kansas  9/9/2016  9/29/2016                 Ipsos    A-
#
#        ...  adjpoll_clinton adjpoll_trump  adjpoll_johnson  adjpoll_mcmullin  \
# ...

# %%
polls.sort_values('state')
# Out:
#        cycle     branch        type                        matchup  \
# 514     2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 5796    2016  President    now-cast  Clinton vs. Trump vs. Johnson
# 10903   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 6238    2016  President    now-cast  Clinton vs. Trump vs. Johnson
# 10431   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# ...      ...        ...         ...                            ...
# 9151    2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 2144    2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 1336    2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 735     2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 5160    2016  President    now-cast  Clinton vs. Trump vs. Johnson
#
#       forecastdate    state   startdate     enddate                 pollster  \
# 514        11/8/16  Alabama   10/4/2016   11/6/2016                   YouGov
# ...

# %% [markdown]
# ## Use Tab completion and tooltips

# %%
polls.sort_values('state', ascending=False)
# Out:
#        cycle     branch        type                        matchup  \
# 429     2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 1323    2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 2423    2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 970     2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 5465    2016  President    now-cast  Clinton vs. Trump vs. Johnson
# ...      ...        ...         ...                            ...
# 3139    2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 2415    2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 6634    2016  President    now-cast  Clinton vs. Trump vs. Johnson
# 11555   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 8930    2016  President  polls-only  Clinton vs. Trump vs. Johnson
#
#       forecastdate    state   startdate     enddate                 pollster  \
# 429        11/8/16  Wyoming   10/5/2016  10/11/2016    University of Wyoming
# ...

# %%
polls.sort_values('startdate', ascending=False, inplace=True)

# %%
# %time polls = pd.read_csv(poll_url)
polls
# Out:
# CPU times: total: 31.2 ms
# Wall time: 37.4 ms
#        cycle     branch        type                        matchup  \
# 0       2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 1       2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 2       2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 3       2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 4       2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# ...      ...        ...         ...                            ...
# 12619   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12620   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12621   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12622   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12623   2016  President  polls-only  Clinton vs. Trump vs. Johnson
#
#       forecastdate          state   startdate    enddate  \
# ...

# %%
# %%time
polls = polls.sort_values('startdate', ascending=False)
polls
# Out:
# CPU times: total: 15.6 ms
# Wall time: 7.34 ms
#        cycle     branch        type                        matchup  \
# 10862   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 10620   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 6662    2016  President    now-cast  Clinton vs. Trump vs. Johnson
# 3022    2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 10716   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# ...      ...        ...         ...                            ...
# 3981    2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 4013    2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 12439   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 8231    2016  President    now-cast  Clinton vs. Trump vs. Johnson
# 4023    2016  President  polls-plus  Clinton vs. Trump vs. Johnson
#
#       forecastdate     state  startdate    enddate              pollster  \
# ...

# %%
# %whos
# Out:
# Variable               Type         Data/Info
# ---------------------------------------------
# dataframe_columns      function     <function dataframe_colum<...>ns at 0x00000208163A9D00>
# dataframe_hash         function     <function dataframe_hash at 0x00000208163AAB60>
# dtypes_str             function     <function dtypes_str at 0x00000208163A98A0>
# get_dataframes         function     <function get_dataframes at 0x00000208163AA7A0>
# getpass                module       <module 'getpass' from 'C<...>conda3\\Lib\\getpass.py'>
# hashlib                module       <module 'hashlib' from 'C<...>conda3\\Lib\\hashlib.py'>
# import_pandas_safely   function     <function import_pandas_s<...>ly at 0x000002081648C0E0>
# is_data_frame          function     <function is_data_frame at 0x0000020816328720>
# item1                  int          1
# item2                  int          2
# item3                  int          3
# item4                  int          4
# ...

# %%
item1 = 1
item2 = 2
item3 = 3
item4 = 4
item5 = 5
[item1,item2,item3,item4,item5]
# Out:
# [1, 2, 3, 4, 5]
